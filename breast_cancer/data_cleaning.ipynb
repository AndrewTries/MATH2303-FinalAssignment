# %%
'''We need to split the dataset into two, one consisting of features only,
    and the other is targets.'''

import pandas as pd

# original dataset
df = pd.read_csv("cancer_historical.csv")

# features only df
X = df.drop("TumorType", axis=1)
# target 
Y = pd.get_dummies(df["TumorType"], dtype=int)

# save the new datasets
#X.to_csv("features.csv", index=False)
Y.to_csv("targets.csv", index=False)
